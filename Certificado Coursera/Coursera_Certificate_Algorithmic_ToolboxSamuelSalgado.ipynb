# %% [markdown]
# # **Certificado Coursera**

# %% [markdown]
# [Perfil LinkedIn](https://www.linkedin.com/in/samuel-ricardo-salgado-rivera-998b9220a/)

# %% [markdown]
# ![imagen_2021-08-08_013009.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
